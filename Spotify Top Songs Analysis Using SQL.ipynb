# %%
import pandas as pd
import sqlite3

# %%
df=pd.read_csv('top50.csv',encoding="ISO-8859-1",index_col=[0])
df.columns=df.columns.str.strip()
df.columns=df.columns.str.replace(".","")
df.head()
# Out:
# C:\Users\saipu\AppData\Local\Temp\ipykernel_11128\4159594600.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns=df.columns.str.replace(".","")
#                          TrackName     ArtistName           Genre  \
# 1                         Señorita   Shawn Mendes    canadian pop
# 2                            China       Anuel AA  reggaeton flow
# 3    boyfriend (with Social House)  Ariana Grande       dance pop
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    BeatsPerMinute  Energy  Danceability  LoudnessdB  Liveness  Valence  \
# 1             117      55            76          -6         8       75
# 2             105      81            79          -4         8       61
# ...

# %%
conn=sqlite3.connect('database.db')
c=conn.cursor()

# %%
df.to_sql("TopSongss",conn)
# Out:
# 50

# %%
c.execute('''SELECT*from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#     index                                          TrackName  \
# 0       1                                           Señorita
# 1       2                                              China
# 2       3                      boyfriend (with Social House)
# 3       4                    Beautiful People (feat. Khalid)
# 4       5                        Goodbyes (Feat. Young Thug)
# 5       6                  I Don't Care (with Justin Bieber)
# 6       7                                             Ransom
# 7       8                                  How Do You Sleep?
# 8       9                              Old Town Road - Remix
# 9      10                                            bad guy
# 10     11                                           Callaita
# 11     12              Loco Contigo (feat. J. Balvin & Tyga)
# 12     13                                  Someone You Loved
# 13     14                                 Otro Trago - Remix
# ...

# %% [markdown]
# # Artistname

# %%
c.execute('''SELECT ArtistName,count(*)from TopSongss group by ArtistName order by count(*)desc;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#           ArtistName  count(*)
# 0         Ed Sheeran         4
# 1   The Chainsmokers         2
# 2       Shawn Mendes         2
# 3               Sech         2
# 4        Post Malone         2
# 5         Marshmello         2
# 6          Lil Nas X         2
# 7           J Balvin         2
# 8      Billie Eilish         2
# 9      Ariana Grande         2
# 10        Young Thug         1
# 11               Y2K         1
# 12       Tones and I         1
# 13      Taylor Swift         1
# 14         Sam Smith         1
# 15           ROSALÍA         1
# 16         Nicky Jam         1
# 17     Martin Garrix         1
# 18            Maluma         1
# 19            MEDUZA         1
# 20             Lunay         1
# 21             Lizzo         1
# 22         Lil Tecca         1
# 23     Lewis Capaldi         1
# 24              Lauv         1
# 25         Lady Gaga         1
# 26              Kygo         1
# 27            Khalid         1
# 28        Katy Perry         1
# ...

# %%
c.execute('''SELECT count(*) from TopSongss
where TrackName like '%feat%'
or TrackName like '%ft%'
or TrackName like "%with%";''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    count(*)
# 0        13

# %% [markdown]
# # Genre

# %%
c.execute('''SELECT Genre,count(*)
from TopSongss
group by Genre
order by count(*) desc;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                Genre  count(*)
# 0          dance pop         8
# 1                pop         7
# 2              latin         5
# 3                edm         3
# 4   canadian hip hop         3
# 5     reggaeton flow         2
# 6          reggaeton         2
# 7     panamanian pop         2
# 8         electropop         2
# 9            dfw rap         2
# 10       country rap         2
# 11      canadian pop         2
# 12           brostep         2
# 13        trap music         1
# 14    r&b en espanol         1
# 15         pop house         1
# 16       escape room         1
# 17          boy band         1
# 18          big room         1
# 19    australian pop         1
# 20       atl hip hop         1

# %%
c.execute('''SELECT count(*) as 'PopSongs'
from TopSongss
where Genre like '%pop%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    PopSongs
# 0        23

# %%
c.execute('''SELECT count(*) as 'RapSongs'
from TopSongss
where Genre like '%rap%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    RapSongs
# 0         5

# %%
c.execute('''SELECT count(*) as 'HipHopSongs'
from TopSongss
where Genre like '%hip hop%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    HipHopSongs
# 0            4

# %%
c.execute('''SELECT count(*) as ReggaetonSongs
from TopSongss
where Genre like '%reggaeton%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    ReggaetonSongs
# 0               4

# %% [markdown]
# # Beats Per Minute

# %%
c.execute('''SELECT avg(BeatsPerMinute)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(BeatsPerMinute)
# 0               120.06

# %%
c.execute('''SELECT TrackName,BeatsPerMinute,
(case when BeatsPerMinute > 120.06 then 'Above Average'
when BeatsPerMinute = 120.06 then 'Average'
when BeatsPerMinute < 120.06 then 'Below Average' end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  BeatsPerMinute CompareAverage
# 0                           Señorita             117  Below Average
# 1                              China             105  Below Average
# 2      boyfriend (with Social House)             190  Above Average
# 3    Beautiful People (feat. Khalid)              93  Below Average
# 4        Goodbyes (Feat. Young Thug)             150  Above Average
# 5  I Don't Care (with Justin Bieber)             102  Below Average
# 6                             Ransom             180  Above Average
# 7                  How Do You Sleep?             111  Below Average
# 8              Old Town Road - Remix             136  Above Average
# 9                            bad guy             135  Above Average

# %%
c.execute('''SELECT TrackName,BeatsPerMinute,
(case when BeatsPerMinute between 110.06 and 130.06 then 'Within 10'
when (BeatsPerMinute between 100.06 and 110.05) or (BeatsPerMinute between 130.07 and 140.06) then 'Within20'
when (BeatsPerMinute between 90.06 and 100.05) or (BeatsPerMinute between 140.07 and 150.06)then 'Within30'
else 'Greater than 30'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  BeatsPerMinute  \
# 0                                            Señorita             117
# 1                                               China             105
# 2                       boyfriend (with Social House)             190
# 3                     Beautiful People (feat. Khalid)              93
# 4                         Goodbyes (Feat. Young Thug)             150
# 5                   I Don't Care (with Justin Bieber)             102
# 6                                              Ransom             180
# 7                                   How Do You Sleep?             111
# 8                               Old Town Road - Remix             136
# 9                                             bad guy             135
# 10                                           Callaita             176
# 11              Loco Contigo (feat. J. Balvin & Tyga)              96
# ...

# %%
c.execute('''SELECT
sum(case when BeatsPerMinute between 110.06 and 130.06 then 1
else 0
end)as Within10,
sum(case when (BeatsPerMinute between 100.06 and 110.05) or (BeatsPerMinute between 130.07 and 140.06) then 1
else 0
end)as Within20,
sum(case when (BeatsPerMinute between 90.06 and 100.05) or (BeatsPerMinute between 140.07 and 150.06) then 1
else 0
end)as Within30,
sum(case when (BeatsPerMinute < 90.06) or (BeatsPerMinute > 150.06) then 1
else 0
end)as Greater30
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within10  Within20  Within30  Greater30
# 0         6        12        18         14

# %% [markdown]
# # Energy

# %%
c.execute('''SELECT avg(Energy)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Energy)
# 0        64.06

# %%
c.execute('''SELECT TrackName,Energy,
(case when Energy > 64.06 then 'Above Average'
when Energy = 64.06 then 'Average'
when Energy < 64.06 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Energy CompareAverage
# 0                           Señorita      55  Below Average
# 1                              China      81  Above Average
# 2      boyfriend (with Social House)      80  Above Average
# 3    Beautiful People (feat. Khalid)      65  Above Average
# 4        Goodbyes (Feat. Young Thug)      65  Above Average
# 5  I Don't Care (with Justin Bieber)      68  Above Average
# 6                             Ransom      64  Below Average
# 7                  How Do You Sleep?      68  Above Average
# 8              Old Town Road - Remix      62  Below Average
# 9                            bad guy      43  Below Average

# %%
c.execute('''SELECT TrackName,Energy,
(case
when Energy between 54.06 and 74.06 then 'Within10'
when (Energy between 44.06 and 54.05) or (Energy between 74.07 and 84.06) then 'Within20'
when (Energy between 34.06 and 44.05) or (Energy between 84.07 and 94.06) then 'Within30'
else 'Greater than 30'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Energy   CompareAverage
# 0                                            Señorita      55         Within10
# 1                                               China      81         Within20
# 2                       boyfriend (with Social House)      80         Within20
# 3                     Beautiful People (feat. Khalid)      65         Within10
# 4                         Goodbyes (Feat. Young Thug)      65         Within10
# 5                   I Don't Care (with Justin Bieber)      68         Within10
# 6                                              Ransom      64         Within10
# 7                                   How Do You Sleep?      68         Within10
# 8                               Old Town Road - Remix      62         Within10
# 9                                             bad guy      43         Within30
# 10                                           Callaita      62         Within10
# ...

# %%
c.execute('''SELECT
sum(case when Energy between 54.06 and 74.06 then 1
else 0
end)as Within10,
sum(case when (Energy between 44.06 and 54.05) or (Energy between 74.07 and 84.06) then 1
else 0
end)as Within20,
sum(case when (Energy between 34.06 and 44.05) or (Energy between 84.07 and 94.06) then 1
else 0
end)as Within30,
sum(case when (Energy < 34.06) or (Energy > 94.06) then 1
else 0
end)as Greater30
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within10  Within20  Within30  Greater30
# 0        25        17         7          1

# %% [markdown]
# # Danceability

# %%
c.execute('''SELECT avg(Danceability)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Danceability)
# 0              71.38

# %%
c.execute('''SELECT TrackName,Danceability,
(case
when Danceability between 61.38 and 81.38 then 'Within10'
when (Danceability between 51.38 and 61.37) or (Danceability between 81.39 and 91.38) then 'Within20'
when (Danceability between 41.38 and 51.37) or (Danceability between 91.38 and 101.38) then 'Within30'
else 'Greater than 30'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Danceability  \
# 0                                            Señorita            76
# 1                                               China            79
# 2                       boyfriend (with Social House)            40
# 3                     Beautiful People (feat. Khalid)            64
# 4                         Goodbyes (Feat. Young Thug)            58
# 5                   I Don't Care (with Justin Bieber)            80
# 6                                              Ransom            75
# 7                                   How Do You Sleep?            48
# 8                               Old Town Road - Remix            88
# 9                                             bad guy            70
# 10                                           Callaita            61
# 11              Loco Contigo (feat. J. Balvin & Tyga)            82
# 12                                  Someone You Loved            50
# ...

# %%
c.execute('''SELECT
sum(case when Danceability between 61.38 and 81.38 then 1
else 0
end)as Within10,
sum(case when (Danceability between 51.38 and 61.37) or (Danceability between 81.39 and 91.38) then 1
else 0
end)as Within20,
sum(case when (Danceability between 41.38 and 51.37) or (Danceability between 91.38 and 101.38) then 1
else 0
end)as Within30,
sum(case when (Danceability < 41.38) or (Danceability > 101.38) then 1
else 0
end)as Greater30
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within10  Within20  Within30  Greater30
# 0        34        12         2          2

# %% [markdown]
# # Loudness

# %%
c.execute('''SELECT avg(LoudnessdB)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(LoudnessdB)
# 0            -5.66

# %%
c.execute('''SELECT TrackName,LoudnessdB,
(case 
when LoudnessdB > -5.66 then 'Above Average'
when Energy = -5.66 then 'Average'
when Energy < -5.66 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  LoudnessdB CompareAverage
# 0                           Señorita          -6           None
# 1                              China          -4  Above Average
# 2      boyfriend (with Social House)          -4  Above Average
# 3    Beautiful People (feat. Khalid)          -8           None
# 4        Goodbyes (Feat. Young Thug)          -4  Above Average
# 5  I Don't Care (with Justin Bieber)          -5  Above Average
# 6                             Ransom          -6           None
# 7                  How Do You Sleep?          -5  Above Average
# 8              Old Town Road - Remix          -6           None
# 9                            bad guy         -11           None

# %%
c.execute('''SELECT TrackName,LoudnessdB,
(case
when LoudnessdB between -6.66 and -4.66 then 'Within1'
when (LoudnessdB between -7.66 and -6.67) or (LoudnessdB between -4.65 and -3.66) then 'Within2'
when (LoudnessdB between -8.66 and -7.67) or (LoudnessdB between -3.65 and -2.66) then 'Within3'
else 'Greater than 3'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  LoudnessdB  \
# 0                                            Señorita          -6
# 1                                               China          -4
# 2                       boyfriend (with Social House)          -4
# 3                     Beautiful People (feat. Khalid)          -8
# 4                         Goodbyes (Feat. Young Thug)          -4
# 5                   I Don't Care (with Justin Bieber)          -5
# 6                                              Ransom          -6
# 7                                   How Do You Sleep?          -5
# 8                               Old Town Road - Remix          -6
# 9                                             bad guy         -11
# 10                                           Callaita          -5
# 11              Loco Contigo (feat. J. Balvin & Tyga)          -4
# 12                                  Someone You Loved          -6
# ...

# %%
c.execute('''SELECT
sum(case when LoudnessdB between -6.66 and -4.66 then 1
else 0
end)as Within1,
sum(case when (LoudnessdB between -7.66 and -6.67) or (LoudnessdB between -4.65 and -3.66) then 1
else 0
end)as Within2,
sum(case when (LoudnessdB between -8.66 and -7.67) or (LoudnessdB between -3.65 and -2.66) then 1
else 0
end)as Within3,
sum(case when (LoudnessdB < -8.66) or (LoudnessdB > -2.66) then 1
else 0
end)as Greater3
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within1  Within2  Within3  Greater3
# 0       21       17        6         6

# %% [markdown]
# # Liveness

# %%
c.execute('''SELECT avg(Liveness)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Liveness)
# 0          14.66

# %%
c.execute('''SELECT TrackName,Liveness,
(case 
when Liveness > 14.66 then 'Above Average'
when Liveness = 14.66 then 'Average'
when Liveness < 14.66 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Liveness CompareAverage
# 0                           Señorita         8  Below Average
# 1                              China         8  Below Average
# 2      boyfriend (with Social House)        16  Above Average
# 3    Beautiful People (feat. Khalid)         8  Below Average
# 4        Goodbyes (Feat. Young Thug)        11  Below Average
# 5  I Don't Care (with Justin Bieber)         9  Below Average
# 6                             Ransom         7  Below Average
# 7                  How Do You Sleep?         8  Below Average
# 8              Old Town Road - Remix        11  Below Average
# 9                            bad guy        10  Below Average

# %%
c.execute('''SELECT TrackName,Liveness,
(case
when Liveness between 11.66 and 17.66 then 'Within3'
when (Liveness between 8.66 and 11.65) or (Liveness between 17.67 and 20.66) then 'Within6'
when (Liveness between 5.66 and 8.65) or (Liveness between 20.67 and 23.66) then 'Within9'
else 'Greater than 3'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Liveness  \
# 0                                            Señorita         8
# 1                                               China         8
# 2                       boyfriend (with Social House)        16
# 3                     Beautiful People (feat. Khalid)         8
# 4                         Goodbyes (Feat. Young Thug)        11
# 5                   I Don't Care (with Justin Bieber)         9
# 6                                              Ransom         7
# 7                                   How Do You Sleep?         8
# 8                               Old Town Road - Remix        11
# 9                                             bad guy        10
# 10                                           Callaita        24
# 11              Loco Contigo (feat. J. Balvin & Tyga)        15
# 12                                  Someone You Loved        11
# 13                                 Otro Trago - Remix         6
# ...

# %%
c.execute('''SELECT
sum(case when Liveness between 11.66 and 17.66 then 1
else 0
end)as Within3,
sum(case when (Liveness between 8.66 and 11.65) or (Liveness between 17.67 and 20.66) then 1
else 0
end)as Within6,
sum(case when (Liveness between 5.66 and 8.65) or (Liveness between 20.67 and 23.66) then 1
else 0
end)as Within9,
sum(case when (Liveness< 5.66) or (Liveness > 23.66) then 1
else 0
end)as Greater9
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within3  Within6  Within9  Greater9
# 0       12       15       15         8

# %% [markdown]
# # Valence

# %%
c.execute('''SELECT avg(Valence)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Valence)
# 0          54.6

# %%
c.execute('''SELECT TrackName,Valence,
(case 
when Valence > 54.6 then 'Above Average'
when Valence = 54.6 then 'Average'
when valence < 54.6 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Valence CompareAverage
# 0                           Señorita       75  Above Average
# 1                              China       61  Above Average
# 2      boyfriend (with Social House)       70  Above Average
# 3    Beautiful People (feat. Khalid)       55  Above Average
# 4        Goodbyes (Feat. Young Thug)       18  Below Average
# 5  I Don't Care (with Justin Bieber)       84  Above Average
# 6                             Ransom       23  Below Average
# 7                  How Do You Sleep?       35  Below Average
# 8              Old Town Road - Remix       64  Above Average
# 9                            bad guy       56  Above Average

# %%
c.execute('''SELECT TrackName,Valence,
(case
when Valence between 49.6 and 59.6 then 'Within 5'
when (Valence between 44.6 and 49.5) or (Valence between 59.7 and 65.6) then 'Within 10'
when (valence between 39.6 and 44.5) or (Valence between 59.6 and 69.6) then 'Within 15'
else 'Greater than 15'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Valence  \
# 0                                            Señorita       75
# 1                                               China       61
# 2                       boyfriend (with Social House)       70
# 3                     Beautiful People (feat. Khalid)       55
# 4                         Goodbyes (Feat. Young Thug)       18
# 5                   I Don't Care (with Justin Bieber)       84
# 6                                              Ransom       23
# 7                                   How Do You Sleep?       35
# 8                               Old Town Road - Remix       64
# 9                                             bad guy       56
# 10                                           Callaita       24
# 11              Loco Contigo (feat. J. Balvin & Tyga)       38
# 12                                  Someone You Loved       45
# 13                                 Otro Trago - Remix       76
# ...

# %%
c.execute('''SELECT
sum(case when Valence between 49.6 and 59.6 then 1
else 0
end)as Within5,
sum(case when (Valence between 44.6 and 49.5) or (Valence between 59.7 and 65.6) then 1
else 0
end)as Within10,
sum(case when (Valence between 39.6 and 44.5) or (Valence between 59.6 and 69.6) then 1
else 0
end)as Within15,
sum(case when (Valence< 39.6) or (Liveness > 69.6) then 1
else 0
end)as Greater15
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within5  Within10  Within15  Greater15
# 0        6         7        15         14

# %% [markdown]
# # Length

# %%
c.execute('''SELECT avg(Length)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Length)
# 0       200.96

# %%
c.execute('''SELECT TrackName,Length,
(case 
when Length > 200.96 then 'Above Average'
when Length = 200.96 then 'Average'
when Length < 200.96 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Length CompareAverage
# 0                           Señorita     191  Below Average
# 1                              China     302  Above Average
# 2      boyfriend (with Social House)     186  Below Average
# 3    Beautiful People (feat. Khalid)     198  Below Average
# 4        Goodbyes (Feat. Young Thug)     175  Below Average
# 5  I Don't Care (with Justin Bieber)     220  Above Average
# 6                             Ransom     131  Below Average
# 7                  How Do You Sleep?     202  Above Average
# 8              Old Town Road - Remix     157  Below Average
# 9                            bad guy     194  Below Average

# %%
c.execute('''SELECT TrackName,Length,
(case
when Valence between 190.96 and 210.96 then 'Within 10'
when (Valence between 180.96 and 190.95) or (Valence between 210.97 and 220.96) then 'Within 20'
when (valence between 170.96 and 180.95) or (Valence between 220.97 and 230.96) then 'Within 30'
else 'Greater than 30'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Length   CompareAverage
# 0                                            Señorita     191  Greater than 30
# 1                                               China     302  Greater than 30
# 2                       boyfriend (with Social House)     186  Greater than 30
# 3                     Beautiful People (feat. Khalid)     198  Greater than 30
# 4                         Goodbyes (Feat. Young Thug)     175  Greater than 30
# 5                   I Don't Care (with Justin Bieber)     220  Greater than 30
# 6                                              Ransom     131  Greater than 30
# 7                                   How Do You Sleep?     202  Greater than 30
# 8                               Old Town Road - Remix     157  Greater than 30
# 9                                             bad guy     194  Greater than 30
# 10                                           Callaita     251  Greater than 30
# ...

# %%
c.execute('''SELECT
sum(case when Length between 190.96 and 210.96 then 1
else 0
end)as Within10,
sum(case when (Length between 180.96 and 190.95) or (Length between 210.97 and 220.96) then 1
else 0
end)as Within20,
sum(case when (Length between 170.96 and 180.95) or (Length between 220.97 and 230.96) then 1
else 0
end)as Within30,
sum(case when (Length < 170.96) or (Length > 230.96) then 1
else 0
end)as Greater30
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within10  Within20  Within30  Greater30
# 0        15        10         9         16

# %% [markdown]
# # Speechiness

# %%
c.execute('''SELECT avg(Speechiness)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Speechiness)
# 0             12.48

# %%
c.execute('''SELECT TrackName,Genre,Speechiness
from TopSongss
where Genre like '%rap%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                        TrackName        Genre  Speechiness
# 0                    Goodbyes (Feat. Young Thug)      dfw rap            7
# 1                                         Ransom   trap music           29
# 2                          Old Town Road - Remix  country rap           10
# 3  Sunflower - Spider-Man: Into the Spider-Verse      dfw rap            5
# 4                                         Panini  country rap            8

# %%
c.execute('''SELECT TrackName,Genre,Speechiness
from TopSongss
where Speechiness >=33;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                        TrackName           Genre  Speechiness
# 0  boyfriend (with Social House)       dance pop           46
# 1                        bad guy      electropop           38
# 2                        7 rings       dance pop           33
# 3                     Otro Trago  panamanian pop           34

# %%
c.execute('''SELECT ((SELECT count(*)*1.0
from TopSongss
where Genre like '%pop%' and Speechiness>=33)/count(*)*1.0)*100 as PopPercentWithHighSpeechiness
from TopSongss
where Genre like '%pop%';''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    PopPercentWithHighSpeechiness
# 0                      17.391304

# %%
c.execute('''SELECT TrackName,Speechiness,
(case 
when Speechiness > 12.48 then 'Above Average'
when Speechiness = 12.48 then 'Average'
when Speechiness < 12.48 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Speechiness CompareAverage
# 0                           Señorita            3  Below Average
# 1                              China            9  Below Average
# 2      boyfriend (with Social House)           46  Above Average
# 3    Beautiful People (feat. Khalid)           19  Above Average
# 4        Goodbyes (Feat. Young Thug)            7  Below Average
# 5  I Don't Care (with Justin Bieber)            4  Below Average
# 6                             Ransom           29  Above Average
# 7                  How Do You Sleep?            9  Below Average
# 8              Old Town Road - Remix           10  Below Average
# 9                            bad guy           38  Above Average

# %%
c.execute('''SELECT TrackName,Speechiness,
(case
when Speechiness between 17.16 and 27.16 then 'Within 5'
when (Speechiness between 12.16 and 17.15) or (Speechiness between 27.17 and 32.16) then 'Within 10'
when (Speechiness between 7.16 and 12.15) or (Speechiness between 32.16 and 37.16) then 'Within 15'
else 'Greater than 15'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Speechiness  \
# 0                                            Señorita            3
# 1                                               China            9
# 2                       boyfriend (with Social House)           46
# 3                     Beautiful People (feat. Khalid)           19
# 4                         Goodbyes (Feat. Young Thug)            7
# 5                   I Don't Care (with Justin Bieber)            4
# 6                                              Ransom           29
# 7                                   How Do You Sleep?            9
# 8                               Old Town Road - Remix           10
# 9                                             bad guy           38
# 10                                           Callaita           31
# 11              Loco Contigo (feat. J. Balvin & Tyga)            7
# 12                                  Someone You Loved            3
# ...

# %%
c.execute('''SELECT
sum(case when Speechiness between 17.16 and 27.16 then 1
else 0
end)as Within5,
sum(case when (Speechiness between 12.16 and 17.15) or (Speechiness between 27.17 and 32.16) then 1
else 0
end)as Within10,
sum(case when (Speechiness between 7.16 and 12.15) or (Speechiness between 32.16 and 37.16) then 1
else 0
end)as Within15,
sum(case when (Speechiness < 7.16) or (Speechiness > 37.16) then 1
else 0
end)as Greater15
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within5  Within10  Within15  Greater15
# 0        3         8        11         28

# %% [markdown]
# # Popularity

# %%
c.execute('''SELECT avg(Popularity)
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    avg(Popularity)
# 0             87.5

# %%
c.execute('''SELECT TrackName,Popularity
from TopSongss
order by Popularity desc
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                        TrackName  Popularity
# 0                                        bad guy          95
# 1                    Goodbyes (Feat. Young Thug)          94
# 2                                       Callaita          93
# 3                                          China          92
# 4                                         Ransom          92
# 5       Money In The Grave (Drake ft. Rick Ross)          92
# 6  Sunflower - Spider-Man: Into the Spider-Verse          91
# 7                                    Truth Hurts          91
# 8                            Piece Of Your Heart          91
# 9                                         Panini          91

# %%
c.execute('''SELECT TrackName,Popularity,
(case 
when Popularity > 87.5 then 'Above Average'
when Popularity = 87.5 then 'Average'
when Popularity < 87.5 then 'Below Average'
end)as CompareAverage
from TopSongss
limit 10;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                            TrackName  Popularity CompareAverage
# 0                           Señorita          79  Below Average
# 1                              China          92  Above Average
# 2      boyfriend (with Social House)          85  Below Average
# 3    Beautiful People (feat. Khalid)          86  Below Average
# 4        Goodbyes (Feat. Young Thug)          94  Above Average
# 5  I Don't Care (with Justin Bieber)          84  Below Average
# 6                             Ransom          92  Above Average
# 7                  How Do You Sleep?          90  Above Average
# 8              Old Town Road - Remix          87  Below Average
# 9                            bad guy          95  Above Average

# %%
c.execute('''SELECT TrackName,Popularity,
(case
when Popularity between 84.5 and 90.5 then 'Within 3'
when (Speechiness between 81.5 and 84.4) or (Speechiness between 90.6 and 93.5) then 'Within 6'
when (Speechiness between 78.5 and 81.4) or (Speechiness between 93.6 and 96.5) then 'Within 9'
else 'Greater than 9'
end)as CompareAverage
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#                                             TrackName  Popularity  \
# 0                                            Señorita          79
# 1                                               China          92
# 2                       boyfriend (with Social House)          85
# 3                     Beautiful People (feat. Khalid)          86
# 4                         Goodbyes (Feat. Young Thug)          94
# 5                   I Don't Care (with Justin Bieber)          84
# 6                                              Ransom          92
# 7                                   How Do You Sleep?          90
# 8                               Old Town Road - Remix          87
# 9                                             bad guy          95
# 10                                           Callaita          93
# 11              Loco Contigo (feat. J. Balvin & Tyga)          86
# 12                                  Someone You Loved          88
# ...

# %%
c.execute('''SELECT
sum(case when Popularity between 84.5 and 90.5 then 1
else 0
end)as Within3,
sum(case when (Popularity between 81.5 and 84.4) or (Popularity between 90.6 and 93.5) then 1
else 0
end)as Within6,
sum(case when (Popularity between 78.5 and 81.4) or (Popularity between 93.6 and 96.5) then 1
else 0
end)as Within9,
sum(case when (Popularity < 78.5) or (Popularity > 96.5) then 1
else 0
end)as Greater9
from TopSongss;''')
data=pd.DataFrame(c.fetchall())
data.columns=[x[0] for x in c.description]
data
# Out:
#    Within3  Within6  Within9  Greater9
# 0       26       18        4         2
